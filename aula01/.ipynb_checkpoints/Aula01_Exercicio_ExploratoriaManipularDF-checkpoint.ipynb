# %% [markdown]
# ___
# # Exercício: Exploratória para Manipular um DataFrame
# ___
#
# ## Aula 01

# %% [markdown]
# ## Índice
#
# - [Gapminder](#gap)
# - [Exercício 1](#ex1) **- APS1 disponível no Blackboard**
# - [Exercício 2](#ex2) **- APS1 disponível no Blackboard**
# - [Resumo dos comandos](#resumo-comandos)

# %% [markdown]
# ___
# **IMPORTANTE**: os exercícios marcados com &#x2605;&#x2605;&#x2605; são mais difíceis e vão exigir que você aprenda novas funções do pandas. Recomendamos que vocês tentem fazer esses exercícios mesmo depois da aula.

# %% [markdown]
# <div id="gap"></div>
#
# ___
#
# ## Gapminder
#
# Gapminder é uma fundação sueca independente, sem afiliações políticas, religiosas ou econômicas.
# Possui diversas estatísticas socioeconômicas de quase todos países do mundo que podem ser facilmente obtidas por este [link](https://www.gapminder.org/data/).
#
# Para visualizar relações entre alguns indicadores dos países, veja [aqui](https://www.gapminder.org/tools/)

# %% [markdown]
# O arquivo `Gapminder.xlsx` contém um *dataset* extraída do software R (mais detalhes [aqui](https://rdrr.io/cran/dslabs/man/gapminder.html)).
#
# Essa base de dados precisa de algumas manipulações antes de iniciar a análise exploratória, entretanto, a mesma irá depender do problema traçado. Nesse *dataframe*, os indicadores estão mensurados para 185 países os quais se repetem entre os anos de 1960 e 2016.

# %%
# Importando as bibliotecas necessárias para esta atividade
import pandas as pd
import os

# %%
print(f'Esperamos trabalhar no diretório: \n{os.getcwd()}\n')
# Out:
# Esperamos trabalhar no diretório:
# C:\Users\loren\Repositorios\CD21-2\aula01

# %%
filename = 'Gapminder.xlsx'

if filename in os.listdir():
    print(f'Parece que o arquivo {filename} está na mesma pasta do notebook, yay!')
    
else:
    print(f'Não encontrei o arquivo {filename}')
# Out:
# Parece que o arquivo Gapminder.xlsx está na mesma pasta do notebook, yay!

# %%
gap = pd.read_excel('Gapminder.xlsx')

# %% [markdown]
# Aqui, `gap` é uma variável do tipo `DataFrame`. Cada uma das colunas significa:
#
# - **country**: nome do país;
# - **year**: ano;
# - **infant_mortality**: mortalidade infantil a cada 1000 nascidos;
# - **life_expectancy**: expectativa de vida;
# - **fertility**: número médio de filhos por mulher;
# - **population**: população do país;
# - **gpd**: PIB de acordo com World Bankdev;
# - **continent**: continente;
# - **region**: região geográfica.

# %%
gap.head()
# Out:
#    Unnamed: 0              country  year  infant_mortality  life_expectancy  \
# 0           1              Albania  1960            115.40            62.87
# 1           2              Algeria  1960            148.20            47.50
# 2           3               Angola  1960            208.00            35.98
# 3           4  Antigua and Barbuda  1960               NaN            62.97
# 4           5            Argentina  1960             59.87            65.39
#
#    fertility  population           gdp continent           region
# 0       6.19   1636054.0           NaN    Europe  Southern Europe
# 1       7.65  11124892.0  1.382815e+10    Africa  Northern Africa
# 2       7.32   5270844.0           NaN    Africa    Middle Africa
# 3       4.43     54681.0           NaN  Americas        Caribbean
# 4       3.11  20619075.0  1.083223e+11  Americas    South America

# %% [markdown]
# <div id="ex1"></div>
#
# ___
#
# ### EXERCÍCIO 1
#
# Faça as seguintes manipulações:
#  1. Filtre apenas as linhas do ano 2010 e selecione as variáveis: `country`, `gdp`, `population` e `continent`
#  1. Guarde o subconjunto anterior em um novo `DataFrame` chamado `gap2010` e, nele, crie a variável `gdp_cap` que contenha o PIB per capita.
#  1. Encontre o país com menor PIB per capita em 2010.
#  1. **Preencha o valor do PIB per capita desse país no campo de resposta do questionário do Blackboard (APS1).**
#
# **Dica**: use `gap.dtypes` para saber o tipo de cada variável. Ainda, consulte [aqui](https://cmdlinetips.com/2019/01/3-ways-to-add-new-columns-to-pandas-dataframe/) para entender como criar novas colunas em um *dataframe*.

# %%
# Coloque seu código aqui...
gap.dtypes
# Out:
# Unnamed: 0            int64
# country              object
# year                  int64
# infant_mortality    float64
# life_expectancy     float64
# fertility           float64
# population          float64
# gdp                 float64
# continent            object
# region               object
# dtype: object

# %%
year = gap['year']==2010
gap2010 = gap.loc[year,:]
gap2010
# Out:
#       Unnamed: 0              country  year  infant_mortality  \
# 9250        9251              Albania  2010              14.8
# 9251        9252              Algeria  2010              23.5
# 9252        9253               Angola  2010             109.6
# 9253        9254  Antigua and Barbuda  2010               7.7
# 9254        9255            Argentina  2010              13.0
# ...          ...                  ...   ...               ...
# 9430        9431   West Bank and Gaza  2010              20.2
# 9431        9432              Vietnam  2010              19.8
# 9432        9433                Yemen  2010              42.4
# 9433        9434               Zambia  2010              52.9
# 9434        9435             Zimbabwe  2010              55.8
#
#       life_expectancy  fertility  population           gdp continent  \
# 9250             77.2       1.74   2901883.0  6.137564e+09    Europe
# 9251             76.0       2.82  36036159.0  7.916434e+10    Africa
# 9252             57.6       6.22  21219954.0  2.612566e+10    Africa
# 9253             75.8       2.13     87233.0  8.366868e+08  Americas
# 9254             75.8       2.22  41222875.0  4.344055e+11  Americas
# ...               ...        ...         ...           ...       ...
# 9430             74.3       4.22   4068780.0           NaN      Asia
# 9431             74.5       1.82  88357775.0  6.283222e+10      Asia
# 9432             66.6       4.50  23591972.0  1.463827e+10      Asia
# 9433             53.1       5.81  13917439.0  5.587390e+09    Africa
# 9434             49.1       3.72  13973897.0  4.032423e+09    Africa
#
#                   region
# 9250     Southern Europe
# 9251     Northern Africa
# 9252       Middle Africa
# 9253           Caribbean
# 9254       South America
# ...                  ...
# 9430        Western Asia
# 9431  South-Eastern Asia
# 9432        Western Asia
# 9433      Eastern Africa
# 9434      Eastern Africa
#
# [185 rows x 10 columns]

# %%
gdp = gap2010['gdp']
pop = gap2010['population']
gap2010.loc[:,'GDPcapita'] = gdp/pop
gap2010
# Out:
#       Unnamed: 0              country  year  infant_mortality  \
# 9250        9251              Albania  2010              14.8
# 9251        9252              Algeria  2010              23.5
# 9252        9253               Angola  2010             109.6
# 9253        9254  Antigua and Barbuda  2010               7.7
# 9254        9255            Argentina  2010              13.0
# ...          ...                  ...   ...               ...
# 9430        9431   West Bank and Gaza  2010              20.2
# 9431        9432              Vietnam  2010              19.8
# 9432        9433                Yemen  2010              42.4
# 9433        9434               Zambia  2010              52.9
# 9434        9435             Zimbabwe  2010              55.8
#
#       life_expectancy  fertility  population           gdp continent  \
# 9250             77.2       1.74   2901883.0  6.137564e+09    Europe
# 9251             76.0       2.82  36036159.0  7.916434e+10    Africa
# 9252             57.6       6.22  21219954.0  2.612566e+10    Africa
# 9253             75.8       2.13     87233.0  8.366868e+08  Americas
# 9254             75.8       2.22  41222875.0  4.344055e+11  Americas
# ...               ...        ...         ...           ...       ...
# 9430             74.3       4.22   4068780.0           NaN      Asia
# 9431             74.5       1.82  88357775.0  6.283222e+10      Asia
# 9432             66.6       4.50  23591972.0  1.463827e+10      Asia
# 9433             53.1       5.81  13917439.0  5.587390e+09    Africa
# 9434             49.1       3.72  13973897.0  4.032423e+09    Africa
#
#                   region     GDPcapita
# 9250     Southern Europe   2115.028051
# 9251     Northern Africa   2196.802928
# 9252       Middle Africa   1231.183784
# 9253           Caribbean   9591.402074
# 9254       South America  10537.972673
# ...                  ...           ...
# 9430        Western Asia           NaN
# 9431  South-Eastern Asia    711.111337
# 9432        Western Asia    620.476544
# 9433      Eastern Africa    401.466811
# 9434      Eastern Africa    288.568280
#
# [185 rows x 11 columns]

# %%
menor_GDPcapita = min(gap2010['GDPcapita'])
menor = gap2010['GDPcapita'] == menor_GDPcapita
gap2010.loc[menor,:]
# Out:
#       Unnamed: 0           country  year  infant_mortality  life_expectancy  \
# 9287        9288  Congo, Dem. Rep.  2010              84.8             58.4
#
#       fertility  population           gdp continent         region   GDPcapita
# 9287       6.25  65938712.0  6.961485e+09    Africa  Middle Africa  105.575083

# %% [markdown]
# <div id="ex2"></div>
#
# ___
#
# ### EXERCÍCIO 2 &#x2605;&#x2605;&#x2605;
#
# Faça as seguintes manipulações:
#   1. Encontre os cinco maiores países (em tamanho populacional) do ano de 2015;
#   1. Guarde apenas os nomes desses cinco países em uma lista;
#   1. Considerando a base de dados com todos os anos, filtre as linhas que contenham apenas os cinco países dessa lista e com as colunas  `country`, `year`, `gdp` e `population`. Guarde esse subconjunto em `gap5`;
#   1. No `DataFrame` `gap5`, crie a variável `dollar_day`, a qual representa uma *proxy* da renda per capita diária do país;
#   1. **Preencha o valor da renda per capita diária de cada país no ano de 1960, em ordem crescente. no campo de resposta do questionário do Blackboard (APS1).**
#
# **Dica**: Para filtrar as linhas apenas dos cinco países selecionados no item 1 deste exercício, pesquise por:
#   - `isin`: retorna booleano se conteúdo da variável faz parte ou não de uma lista. Consulte sobre esse comando `isin` [aqui](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isin.html)

# %%
year2015 = gap['year']==2015
gap2015 = gap.loc[year2015,:]
gap2015
# Out:
#        Unnamed: 0              country  year  infant_mortality  \
# 10175       10176              Albania  2015              12.5
# 10176       10177              Algeria  2015              21.9
# 10177       10178               Angola  2015              96.0
# 10178       10179  Antigua and Barbuda  2015               5.8
# 10179       10180            Argentina  2015              11.1
# ...           ...                  ...   ...               ...
# 10355       10356   West Bank and Gaza  2015              18.0
# 10356       10357              Vietnam  2015              17.3
# 10357       10358                Yemen  2015              33.8
# 10358       10359               Zambia  2015              43.3
# 10359       10360             Zimbabwe  2015              46.6
#
#        life_expectancy  fertility  population  gdp continent  \
# 10175             78.0       1.78   2896679.0  NaN    Europe
# 10176             76.4       2.71  39666519.0  NaN    Africa
# 10177             59.6       5.65  25021974.0  NaN    Africa
# 10178             76.4       2.06     91818.0  NaN  Americas
# 10179             76.5       2.15  43416755.0  NaN  Americas
# ...                ...        ...         ...  ...       ...
# 10355             74.6       3.88   4668466.0  NaN      Asia
# 10356             75.4       1.70  93447601.0  NaN      Asia
# 10357             66.0       3.83  26832215.0  NaN      Asia
# 10358             56.7       5.59  16211767.0  NaN    Africa
# 10359             59.3       3.35  15602751.0  NaN    Africa
#
#                    region
# 10175     Southern Europe
# 10176     Northern Africa
# 10177       Middle Africa
# 10178           Caribbean
# 10179       South America
# ...                   ...
# 10355        Western Asia
# 10356  South-Eastern Asia
# 10357        Western Asia
# 10358      Eastern Africa
# 10359      Eastern Africa
#
# [185 rows x 10 columns]

# %%
pop_sorted_gap2015 = gap2015.sort_values(['population'], ascending =False).head()
pop_sorted_gap2015
# Out:
#        Unnamed: 0        country  year  infant_mortality  life_expectancy  \
# 10209       10210          China  2015               9.2             76.2
# 10251       10252          India  2015              37.9             67.2
# 10350       10351  United States  2015               5.6             79.1
# 10252       10253      Indonesia  2015              22.8             71.1
# 10197       10198         Brazil  2015              14.6             74.4
#
#        fertility    population  gdp continent              region
# 10209       1.57  1.376049e+09  NaN      Asia        Eastern Asia
# 10251       2.43  1.311051e+09  NaN      Asia       Southern Asia
# 10350       1.97  3.217736e+08  NaN  Americas    Northern America
# 10252       2.28  2.575638e+08  NaN      Asia  South-Eastern Asia
# 10197       1.78  2.078475e+08  NaN  Americas       South America

# %%
paises_maior_pop = ['China', 'India', 'United States', 'Indonesia', 'Brazil']

# %%
gap5 = gap.loc[gap.country.isin(paises_maior_pop),['country','year','population','gdp']]
gap5
# Out:
#              country  year   population           gdp
# 22            Brazil  1960   72493585.0  1.053434e+11
# 34             China  1960  644450173.0  7.034853e+10
# 76             India  1960  449661874.0  8.104265e+10
# 77         Indonesia  1960   87792512.0  1.844892e+10
# 175    United States  1960  186176524.0  2.479391e+12
# ...              ...   ...          ...           ...
# 10382         Brazil  2016          NaN           NaN
# 10394          China  2016          NaN           NaN
# 10436          India  2016          NaN           NaN
# 10437      Indonesia  2016          NaN           NaN
# 10535  United States  2016          NaN           NaN
#
# [285 rows x 4 columns]

# %%
pib = gap5['gdp']
cap = gap5['population']
gap5['dollar_day'] = pib/(cap*365)
gap5
# Out:
#              country  year   population           gdp  dollar_day
# 22            Brazil  1960   72493585.0  1.053434e+11    3.981207
# 34             China  1960  644450173.0  7.034853e+10    0.299070
# 76             India  1960  449661874.0  8.104265e+10    0.493781
# 77         Indonesia  1960   87792512.0  1.844892e+10    0.575732
# 175    United States  1960  186176524.0  2.479391e+12   36.486084
# ...              ...   ...          ...           ...         ...
# 10382         Brazil  2016          NaN           NaN         NaN
# 10394          China  2016          NaN           NaN         NaN
# 10436          India  2016          NaN           NaN         NaN
# 10437      Indonesia  2016          NaN           NaN         NaN
# 10535  United States  2016          NaN           NaN         NaN
#
# [285 rows x 5 columns]

# %% [markdown]
# <div id="resumo-comandos"></div>
#
# ## Resumo dos Comandos
#
# Aqui você encontra um resumo dos comandos apresentados neste notebook:
#
# - [`dtypes`](#ex1): mostra o tipo de cada variável do *dataframe*.
# - [`isin`](#ex2): avalia, por exemplo, se conteúdo de uma coluna do *dataframe* faz parte ou não de uma lista.
